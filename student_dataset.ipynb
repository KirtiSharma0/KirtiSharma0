# %%
import numpy as np
arr = np.array([10, 20, 30, 40, 50])

arr[1] = 25

print(arr)
# Out:
# [10 25 30 40 50]

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
df = pd.read_excel('/STUDENT.xlsx' )

# %%
df.tail()
# Out:
#    Unnamed: 0  \
# 83        NaN
# 84        NaN
# 85        NaN
# 86        NaN
# 87        NaN
#
#    MANAV RACHNA INTERNATIONAL INSTITUTE OF RESEARCH AND STUDIES (DEEMED TO BE UNIVERSITY), FARIDABAD  \
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
#
#    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 83        NaN        NaN        NaN        NaN        NaN
# 84        NaN        NaN        NaN        NaN        NaN
# 85        NaN        NaN        NaN        NaN        NaN
# 86        NaN        NaN        NaN        NaN        NaN
# 87        NaN        NaN        NaN        NaN        NaN
#
#                Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10   Unnamed: 11  \
# ...

# %%
import pandas as pd
df = pd.DataFrame()
df = pd.read_excel('/STUDENT.xlsx' )
df.tail()
# Out:
#    Semester  S.No. Branch /Course  \
# 81      NaN    NaN            NaN
# 82      NaN    NaN            NaN
# 83      NaN    NaN            NaN
# 84      NaN    NaN            NaN
# 85      NaN    NaN            NaN
#
#    University Registration No. (Issued by R&S Branch)  \
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
#
#    Date of Admission in the Present Class/Course Roll No.  \
# 81                                           NaN      NaN
# 82                                           NaN      NaN
# 83                                           NaN      NaN
# 84                                           NaN      NaN
# 85                                           NaN      NaN
#
# ...

# %%
import pandas as pd
df = pd.DataFrame()
df = pd.read_excel('/STUDENT.xlsx' )
df.head(5)
# Out:
#   Semester  S.No.                           Branch /Course  \
# 0    5CSB1    1.0  B.Tech - Computer Science & Engineering
# 1    5CSB1    2.0  B.Tech - Computer Science & Engineering
# 2    5CSB1    3.0  B.Tech - Computer Science & Engineering
# 3    5CSB1    4.0  B.Tech - Computer Science & Engineering
# 4    5CSB1    5.0  B.Tech - Computer Science & Engineering
#
#   University Registration No. (Issued by R&S Branch)  \
# 0                                        22/FET/0119
# 1                                        22/FET/0120
# 2                                        22/FET/0121
# 3                                        22/FET/0122
# 4                                        22/FET/0123
#
#   Date of Admission in the Present Class/Course          Roll No.  \
# 0                                    29.07.2024  1/22/FET/BCS/065
# 1                                    29.07.2024  1/22/FET/BCS/066
# 2                                    29.07.2024  1/22/FET/BCS/067
# ...

# %%
df.rename(columns={'Branch /Course':'Course'},inplace=True)

# %%
df.head(5)
# Out:
#   Semester  S.No.                                   Course  \
# 0    5CSB1    1.0  B.Tech - Computer Science & Engineering
# 1    5CSB1    2.0  B.Tech - Computer Science & Engineering
# 2    5CSB1    3.0  B.Tech - Computer Science & Engineering
# 3    5CSB1    4.0  B.Tech - Computer Science & Engineering
# 4    5CSB1    5.0  B.Tech - Computer Science & Engineering
#
#   University Registration No. (Issued by R&S Branch)  \
# 0                                        22/FET/0119
# 1                                        22/FET/0120
# 2                                        22/FET/0121
# 3                                        22/FET/0122
# 4                                        22/FET/0123
#
#   Date of Admission in the Present Class/Course          Roll No.  \
# 0                                    29.07.2024  1/22/FET/BCS/065
# 1                                    29.07.2024  1/22/FET/BCS/066
# 2                                    29.07.2024  1/22/FET/BCS/067
# ...

# %%
df.rename(columns={'University Registration No. (Issued by R&S Branch)':'Registration Number'},inplace=True)

# %%
df.head(5)
# Out:
#   Semester  S.No.                                   Course  \
# 0    5CSB1    1.0  B.Tech - Computer Science & Engineering
# 1    5CSB1    2.0  B.Tech - Computer Science & Engineering
# 2    5CSB1    3.0  B.Tech - Computer Science & Engineering
# 3    5CSB1    4.0  B.Tech - Computer Science & Engineering
# 4    5CSB1    5.0  B.Tech - Computer Science & Engineering
#
#   Registration Number Date of Admission in the Present Class/Course  \
# 0         22/FET/0119                                    29.07.2024
# 1         22/FET/0120                                    29.07.2024
# 2         22/FET/0121                                    29.07.2024
# 3         22/FET/0122                                    29.07.2024
# 4         22/FET/0123                                    29.07.2024
#
#            Roll No.  \
# 0  1/22/FET/BCS/065
# 1  1/22/FET/BCS/066
# 2  1/22/FET/BCS/067
# 3  1/22/FET/BCS/068
# 4  1/22/FET/BCS/069
#
# ...

# %%
df.rename(columns={'Date of Admission in the Present Class/Course':'Admission date'},inplace=True)

# %%
df.head(5)
# Out:
#   Semester  S.No.                                   Course  \
# 0    5CSB1    1.0  B.Tech - Computer Science & Engineering
# 1    5CSB1    2.0  B.Tech - Computer Science & Engineering
# 2    5CSB1    3.0  B.Tech - Computer Science & Engineering
# 3    5CSB1    4.0  B.Tech - Computer Science & Engineering
# 4    5CSB1    5.0  B.Tech - Computer Science & Engineering
#
#   Registration Number admission date          Roll No.  \
# 0         22/FET/0119     29.07.2024  1/22/FET/BCS/065
# 1         22/FET/0120     29.07.2024  1/22/FET/BCS/066
# 2         22/FET/0121     29.07.2024  1/22/FET/BCS/067
# 3         22/FET/0122     29.07.2024  1/22/FET/BCS/068
# 4         22/FET/0123     29.07.2024  1/22/FET/BCS/069
#
#   Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN  \
# 0                                   SNEHA SRIVASTAVA
# 1                                        DHRUV RAWAT
# 2                                          HARSHIT .
# ...

# %%
df.rename(columns={'Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN':'Student name'}, inplace=True)

# %%
df.head(5)
# Out:
#   Semester  S.No.                                   Course  \
# 0    5CSB1    1.0  B.Tech - Computer Science & Engineering
# 1    5CSB1    2.0  B.Tech - Computer Science & Engineering
# 2    5CSB1    3.0  B.Tech - Computer Science & Engineering
# 3    5CSB1    4.0  B.Tech - Computer Science & Engineering
# 4    5CSB1    5.0  B.Tech - Computer Science & Engineering
#
#   Registration Number admission date          Roll No.      Student name  \
# 0         22/FET/0119     29.07.2024  1/22/FET/BCS/065  SNEHA SRIVASTAVA
# 1         22/FET/0120     29.07.2024  1/22/FET/BCS/066       DHRUV RAWAT
# 2         22/FET/0121     29.07.2024  1/22/FET/BCS/067         HARSHIT .
# 3         22/FET/0122     29.07.2024  1/22/FET/BCS/068     SARTHAK MONGA
# 4         22/FET/0123     29.07.2024  1/22/FET/BCS/069     DHRUV KAUSHAL
#
#   Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-FN  \
# 0                              AJIT KUMAR SRIVASTAVA
# ...

# %%
df.rename(columns={'Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-FN':'Fathers name'},inplace=True)

# %%
df.head(3)
# Out:
#   Semester  S.No.                                   Course  \
# 0    5CSB1    1.0  B.Tech - Computer Science & Engineering
# 1    5CSB1    2.0  B.Tech - Computer Science & Engineering
# 2    5CSB1    3.0  B.Tech - Computer Science & Engineering
#
#   Registration Number admission date          Roll No.      Student name  \
# 0         22/FET/0119     29.07.2024  1/22/FET/BCS/065  SNEHA SRIVASTAVA
# 1         22/FET/0120     29.07.2024  1/22/FET/BCS/066       DHRUV RAWAT
# 2         22/FET/0121     29.07.2024  1/22/FET/BCS/067         HARSHIT .
#
#             Fathers name  Gender  Religion Category  Aadhaar No. of Student  \
# 0  AJIT KUMAR SRIVASTAVA  FEMALE  HINDUISM  GENERAL            6.033757e+11
# 1     DIGPAL SINGH RAWAT    MALE  HINDUISM  GENERAL            7.805329e+11
# 2                SANDEEP    MALE  HINDUISM      OBC            2.663434e+11
#
#    Updated Mobile No. of Student          Updated E-mail ID    State  \
# ...

# %%
df.rename(columns={'Category':'Category(Gen/SC/ST/OBC)'},inplace=True)

# %%
df.head(3)
# Out:
#   Semester  S.No.                                   Course  \
# 0    5CSB1    1.0  B.Tech - Computer Science & Engineering
# 1    5CSB1    2.0  B.Tech - Computer Science & Engineering
# 2    5CSB1    3.0  B.Tech - Computer Science & Engineering
#
#   Registration Number admission date          Roll No.      Student name  \
# 0         22/FET/0119     29.07.2024  1/22/FET/BCS/065  SNEHA SRIVASTAVA
# 1         22/FET/0120     29.07.2024  1/22/FET/BCS/066       DHRUV RAWAT
# 2         22/FET/0121     29.07.2024  1/22/FET/BCS/067         HARSHIT .
#
#             Fathers name  Gender  Religion Category(Gen/SC/ST/OBC)  \
# 0  AJIT KUMAR SRIVASTAVA  FEMALE  HINDUISM                 GENERAL
# 1     DIGPAL SINGH RAWAT    MALE  HINDUISM                 GENERAL
# 2                SANDEEP    MALE  HINDUISM                     OBC
#
#    Aadhaar No. of Student  Updated Mobile No. of Student  \
# 0            6.033757e+11                     9997419537
# ...
